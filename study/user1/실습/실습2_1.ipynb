# %%
import FinanceDataReader as fdr
import pandas as pd
import matplotlib.pyplot as plt

# %%
# 도움말을 보고자 할때는 ? 를 사용하고 소스코드를 볼 때는 ??를 사용합니다.
# 주피터 노트북에서는 함수나 메소드의 괄호 안에서 shift + tab 키를 누르면 도움말을 볼 수 있습니다.
fdr.StockListing??
# Out:
# Signature: fdr.StockListing(market)
# Docstring: <no docstring>
# Source:
# def StockListing(market):
#     market = market.upper()
#     if market in [ 'NASDAQ', 'NYSE', 'AMEX', 'SSE', 'SZSE', 'HKEX', 'TSE', 'HOSE']:
#         return NaverStockListing(market).read()
#     if market in [ 'KRX', 'KOSPI', 'KOSDAQ', 'KONEX']:
#         return KrxStockListing(market).read()
#     if market in [ 'KRX-DELISTING' ]:
#         return KrxDelisting(market).read()
#     if market in [ 'KRX-ADMINISTRATIVE' ]:
#         return KrxAdministrative(market).read()
#     if market in [ 'S&P500', 'SP500']:
#         return WikipediaStockListing(market).read()
#     else:
#         msg = "market='%s' is not implemented" % market
#         raise NotImplementedError(msg)
# File:      d:\anaconda3\lib\site-packages\financedatareader\data.py
# Type:      function

# %%
# KRX : KRX 종목 전체
# KOSPI : KOSPI 종목
# KOSDAQ : KOSDAQ 종목
# KONEX : KONEX 종목
# NASDAQ : 나스닥 종목
# NYSE : 뉴욕증권거래소 종목
# SP500 : S&P500 종목
fdr.StockListing("KOSDAQ")
# Out:
#       Symbol  Market    Name                    Sector  \
# 0     060310  KOSDAQ      3S             특수 목적용 기계 제조업
# 3     054620  KOSDAQ  APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ   AP시스템             특수 목적용 기계 제조업
# 5     211270  KOSDAQ    AP위성            통신 및 방송 장비 제조업
# 53    035760  KOSDAQ  CJ ENM                  텔레비전 방송업
# ...      ...     ...     ...                       ...
# 6657  024060  KOSDAQ    흥구석유                 기타 전문 도매업
# 6658  010240  KOSDAQ      흥국             특수 목적용 기계 제조업
# 6660  189980  KOSDAQ  흥국에프엔비           비알코올음료 및 얼음 제조업
# 6665  037440  KOSDAQ      희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 6666  238490  KOSDAQ      힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# 5                           위성통신 단말기  2016-03-04         12월
# 53            의류, 생활주방, 가전제품, 보석, 기타  1999-11-23         12월
# ...                              ...         ...         ...
# 6657                            휘발유등  1994-12-07         12월
# 6658               굴삭기 Roller 및 형단조품  2009-05-12         12월
# 6660       과일음료(에이드베이스, 스무디, 착즙쥬스 등)  2015-08-07         12월
# 6665                       설계 및 감리용역  2000-02-03         12월
# 6666  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                      HomePage Region
# 0            박종익, 김세완 (각자 대표이사)          http://www.3sref.com  서울특별시
# 3                           정기로  http://www.apsholdings.co.kr    경기도
# 4                           김영주    http://www.apsystems.co.kr    경기도
# 5                           류장수         http://www.apsi.co.kr  서울특별시
# 53       Minheoi Heo, Minho Hou         http://www.cjmall.com  서울특별시
# ...                         ...                           ...    ...
# 6657                        김상우                           NaN  대구광역시
# 6658                        류명준     http://www.heungkuk.co.kr   충청남도
# 6660                   박철범, 오길영       http://www.hyungkuk.com  서울특별시
# 6665  정영균, 이목운, 허철호, 염두성 (각자대표)         http://www.heerim.com  서울특별시
# 6666                        김주환         http://www.hims.co.kr  인천광역시
#
# [1494 rows x 10 columns]

# %%
# 한국거래소 상장종목 전체 가져오기
df = fdr.StockListing("KRX")

# %%
# 행과 열의 크기를 봅니다.(행, 열) 순
df.shape
# Out:
# (6667, 10)

# %%
# 전체 데이터프레임의 요약정보를 봅니다.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6667 entries, 0 to 6666
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Symbol          6667 non-null   object
#  1   Market          6667 non-null   object
#  2   Name            6667 non-null   object
#  3   Sector          2412 non-null   object
#  4   Industry        2393 non-null   object
#  5   ListingDate     2412 non-null   datetime64[ns]
#  6   SettleMonth     2412 non-null   object
#  7   Representative  2412 non-null   object
#  8   HomePage        2239 non-null   object
#  9   Region          2412 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 572.9+ KB

# %%
# 기술통계 값을 요약합니다.
df.describe()
# Out:
# <ipython-input-7-e99021bae268>:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#         Symbol Market  Name         Sector Industry          ListingDate  \
# count     6667   6667  6667           2412     2393                 2412
# unique    6667      3  6667            158     2241                 1777
# top     245360  KOSPI  조선내화  특수 목적용 기계 제조업   기업인수합병  1976-06-30 00:00:00
# freq         1   5031     1            141       36                    8
# first      NaN    NaN   NaN            NaN      NaN  1956-03-03 00:00:00
# last       NaN    NaN   NaN            NaN      NaN  2021-01-25 00:00:00
#
#        SettleMonth Representative                HomePage Region
# count         2412           2412                    2239   2412
# unique           9           2297                    2218     21
# top            12월              -  http://www.crown.co.kr  서울특별시
# freq          2352              5                       2    972
# first          NaN            NaN                     NaN    NaN
# last           NaN            NaN                     NaN    NaN

# %%
# head 로 미리보기
df.head()
# Out:
#    Symbol  Market    Name           Sector             Industry ListingDate  \
# 0  060310  KOSDAQ      3S    특수 목적용 기계 제조업          반도체 웨이퍼 캐리어  2002-04-23
# 1  095570   KOSPI  AJ네트웍스  산업용 기계 및 장비 임대업  렌탈(파렛트, OA장비, 건설장비)  2015-08-21
# 2  006840   KOSPI   AK홀딩스           기타 금융업                 지주사업  1999-08-11
# 3  054620  KOSDAQ  APS홀딩스           기타 금융업          인터넷 트래픽 솔루션  2001-12-04
# 4  265520  KOSDAQ   AP시스템    특수 목적용 기계 제조업          디스플레이 제조 장비  2017-04-07
#
#   SettleMonth      Representative                       HomePage Region
# 0         03월  박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1         12월                 이현우         http://www.ajnet.co.kr  서울특별시
# 2         12월   채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3         12월                 정기로   http://www.apsholdings.co.kr    경기도
# 4         12월                 김영주     http://www.apsystems.co.kr    경기도

# %%
# to_csv로 Dataframe을 데이터 저장용 파일인 CSV 파일로 바꿀 수 있습니다.
df.to_csv("실습2_1.csv", index=False)

# %%
# CSV로 저장된 파일을 다시 DataFrame으로 읽어서 확인해 봅니다.
df_csv = pd.read_csv("실습2_1.csv")
df_csv
# Out:
#       Symbol  Market     Name                    Sector  \
# 0     060310  KOSDAQ       3S             특수 목적용 기계 제조업
# 1     095570   KOSPI   AJ네트웍스           산업용 기계 및 장비 임대업
# 2     006840   KOSPI    AK홀딩스                    기타 금융업
# 3     054620  KOSDAQ   APS홀딩스                    기타 금융업
# 4     265520  KOSDAQ    AP시스템             특수 목적용 기계 제조업
# ...      ...     ...      ...                       ...
# 6662  000547   KOSPI  흥국화재2우B                       NaN
# 6663  000545   KOSPI    흥국화재우                       NaN
# 6664  003280   KOSPI     흥아해운                    해상 운송업
# 6665  037440  KOSDAQ       희림  건축기술, 엔지니어링 및 관련 기술 서비스업
# 6666  238490  KOSDAQ       힘스             특수 목적용 기계 제조업
#
#                             Industry ListingDate SettleMonth  \
# 0                        반도체 웨이퍼 캐리어  2002-04-23         03월
# 1                렌탈(파렛트, OA장비, 건설장비)  2015-08-21         12월
# 2                               지주사업  1999-08-11         12월
# 3                        인터넷 트래픽 솔루션  2001-12-04         12월
# 4                        디스플레이 제조 장비  2017-04-07         12월
# ...                              ...         ...         ...
# 6662                             NaN         NaN         NaN
# 6663                             NaN         NaN         NaN
# 6664                  외항화물운송업(케미컬탱커)  1976-06-29         12월
# 6665                       설계 및 감리용역  2000-02-03         12월
# 6666  OLED Mask 인장기, OLED Mask 검사기 등  2017-07-20         12월
#
#                  Representative                       HomePage Region
# 0            박종익, 김세완 (각자 대표이사)           http://www.3sref.com  서울특별시
# 1                           이현우         http://www.ajnet.co.kr  서울특별시
# 2             채형석, 이석주(각자 대표이사)  http://www.aekyunggroup.co.kr  서울특별시
# 3                           정기로   http://www.apsholdings.co.kr    경기도
# 4                           김영주     http://www.apsystems.co.kr    경기도
# ...                         ...                            ...    ...
# 6662                        NaN                            NaN    NaN
# 6663                        NaN                            NaN    NaN
# 6664                        이환구         http://www.heung-a.com  서울특별시
# 6665  정영균, 이목운, 허철호, 염두성 (각자대표)          http://www.heerim.com  서울특별시
# 6666                        김주환          http://www.hims.co.kr  인천광역시
#
# [6667 rows x 10 columns]
